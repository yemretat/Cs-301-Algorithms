# %%
import copy
import time


# Class to represent a graph
class Graph:

    def _init_(self, vertices):
        self.V = vertices  # No. of vertices
        self.graph = []  # default dictionary to store graph

    # function to add an edge to graph
    def addedge(self, u, v, w):  # u source v destination w weight
        self.graph.append([u, v, w])

    # utility function used to print the solution
    def printArr(self, dist):
        print("Vertex   Distance from Source")
        for i in range(self.V):
            print("% d \t\t % d" % (i, dist[i]))

    def BellmanFord(self, src, want):
        # Step 1: Initialize distances from src to all other vertices
        # as INFINITE
        dist = [float("Inf")] * self.V
        dist[src] = 0
        # Step 2: Relax all edges |V| - 1 times. A simple shortest
        # path from src to any other vertex can have at-most |V| - 1
        # edges

        for i in range(self.V - 1):
            for u, v, w in self.graph:
                if dist[u] != float("Inf") and dist[u] + w < dist[v]:
                    dist[v] = dist[u] + w
        return min(dist[want], dist[want + totalnumbercit])

    def frombustotrain(self):  # grapha diyoruz
        for i in range(totalnumbercit):
            bus.addedge(i, totalnumbercit + i, 0)  # iki tane graph bi train bi bus 6 lık mesela 0 ve 7 aynı
            # ikisi bir tane ama aynı gibi

    def fromtraintobus(self):
        for i in range(totalnumbercit):
            train.addedge(totalnumbercit + i, i, 0)


# ----------------------------------------
totalnumbercit = int(input("How many cities do you want to use in your map :"))

g = Graph(totalnumbercit * 2)
'''
for i in range(totalnumbercit):
    for k in range(totalnumbercit):
        if k > i:  # this is used because it shouldnt be duplicated
            #            ind = input("Is there any train station between i and k (1/2) :")# 1 is yes,2 is No
            if ind == "1":
                #               weight = int(input("What is the average time by train between i and k (number) :"))#getting weights 
                g.addedge(totalnumbercit + i, totalnumbercit + k,
                          weight)  # there is a only one graph I use more adding city numbers instead of creating new graph 
                g.addedge(totalnumbercit + k, totalnumbercit + i, weight)
                # if from a to b there is train station that means there is b to a train station

            #            ind2 = input("Is there any bus station between i and k (1/2) :")
            if ind2 == "Yes":
                weight2 = int(input("What is the average time by bus between i and k (number) :"))
                g.addedge(i, k, weight2)
                g.addedge(k, i, weight2)
'''
train = copy.deepcopy(g)
bus = copy.copy(g)
train.fromtraintobus()
bus.frombustotrain()
end = 0


#V size 9
g.addedge(0,1,4)
g.addedge(1,0,4)
g.addedge(1,2,1)
g.addedge(2,1,1)
g.addedge(2,3,4)
g.addedge(3,2,4)
g.addedge(2,4,1)
g.addedge(4,2,1)
g.addedge(3,4,2)
g.addedge(4,3,2)
g.addedge(4,5,3)
g.addedge(5,4,3)
g.addedge(5,6,4)
g.addedge(6,5,4)
g.addedge(6,7,2)
g.addedge(7,6,2)
g.addedge(7,8,10)
g.addedge(8,7,10)
g.addedge(9,10,1)
g.addedge(10,11,4)
g.addedge(11,12,1)
g.addedge(11,13,4)
g.addedge(12,13,1)
g.addedge(13,14,3)
g.addedge(14,15,1)
g.addedge(15,16,5)
g.addedge(16,17,3)
g.addedge(10,9,1)
g.addedge(11,10,4)
g.addedge(12,11,1)
g.addedge(13,11,4)
g.addedge(13,12,1)
g.addedge(14,13,3)
g.addedge(15,14,1)
g.addedge(16,15,5)
g.addedge(17,16,3)
'''

'''

#V size 3

g.addedge(0,1,2)
g.addedge(1,2,10)
g.addedge(0,2,5)
g.addedge(3,4,8)
g.addedge(4,5,1)
g.addedge(3,5,6)
g.addedge(1,0,2)
g.addedge(2,1,10)
g.addedge(2,0,5)
g.addedge(4,3,8)
g.addedge(5,4,1)
g.addedge(5,3,6)
'''

'''

#V size 4

g.addedge(0,1,1)
g.addedge(1,2,2)
g.addedge(2,3,3)
g.addedge(4,5,2)
g.addedge(5,6,1)
g.addedge(6,7,5)
g.addedge(1,0,1)
g.addedge(2,1,2)
g.addedge(3,2,3)
g.addedge(5,4,2)
g.addedge(6,5,1)
g.addedge(7,6,5)
'''

'''

#V size 5

g.addedge(0,1,3)
g.addedge(0,2,5)
g.addedge(1,2,4)
g.addedge(1,4,9)
g.addedge(2,3,3)
g.addedge(2,4,6)
g.addedge(3,4,4)
g.addedge(5,6,1)
g.addedge(5,7,2)
g.addedge(6,7,2)
g.addedge(6,9,9)
g.addedge(7,8,1)
g.addedge(7,9,6)
g.addedge(8,9,8)
g.addedge(1,0,3)
g.addedge(2,0,5)
g.addedge(2,1,4)
g.addedge(4,1,9)
g.addedge(3,2,3)
g.addedge(4,2,6)
g.addedge(4,3,4)
g.addedge(6,5,1)
g.addedge(7,5,2)
g.addedge(7,6,2)
g.addedge(9,6,9)
g.addedge(8,7,1)
g.addedge(9,7,6)
g.addedge(9,88,8)
'''
'''

#V size 6

g.addedge(0,1,1)
g.addedge(1,2,2)
g.addedge(2,3,3)
g.addedge(4,5,2)
g.addedge(6,7,1)
g.addedge(7,8,3)
g.addedge(8,9,2)
g.addedge(10,11,5)
g.addedge(1,0,1)
g.addedge(2,1,2)
g.addedge(3,2,3)
g.addedge(5,4,2)
g.addedge(7,6,1)
g.addedge(8,7,3)
g.addedge(9,8,2)
g.addedge(11,10,5)
'''

#V size 9
bus.addedge(0,1,4)
bus.addedge(1,0,4)
bus.addedge(1,2,1)
bus.addedge(2,1,1)
bus.addedge(2,3,4)
bus.addedge(3,2,4)
bus.addedge(2,4,1)
bus.addedge(4,2,1)
bus.addedge(3,4,2)
bus.addedge(4,3,2)
bus.addedge(4,5,3)
bus.addedge(5,4,3)
bus.addedge(5,6,4)
bus.addedge(6,5,4)
bus.addedge(6,7,2)
bus.addedge(7,6,2)
bus.addedge(7,8,10)
bus.addedge(8,7,10)
train.addedge(0,1,1)
train.addedge(1,2,4)
train.addedge(2,3,1)
train.addedge(2,4,4)
train.addedge(3,4,1)
train.addedge(4,5,3)
train.addedge(5,6,1)
train.addedge(6,7,5)
train.addedge(7,8,3)
train.addedge(1,0,1)
train.addedge(2,1,4)
train.addedge(3,2,1)
train.addedge(4,2,4)
train.addedge(4,3,1)
train.addedge(5,4,3)
train.addedge(6,5,1)
train.addedge(7,6,5)
train.addedge(8,7,3)
'''

'''

#V size 3

bus.addedge(0,1,2)
bus.addedge(1,2,10)
bus.addedge(0,2,5)
train.addedge(0,1,8)
train.addedge(1,2,1)
train.addedge(0,2,6)
bus.addedge(1,0,2)
bus.addedge(2,1,10)
bus.addedge(2,0,5)
train.addedge(1,0,8)
train.addedge(2,1,1)
train.addedge(2,0,6)
'''

'''

#V size 4

bus.addedge(0,1,1)
bus.addedge(1,2,2)
bus.addedge(2,3,3)
train.addedge(0,1,2)
train.addedge(1,2,1)
train.addedge(2,3,5)
bus.addedge(1,0,1)
bus.addedge(2,1,2)
bus.addedge(3,2,3)
train.addedge(1,0,2)
train.addedge(2,1,1)
train.addedge(3,2,5)
'''

'''

#V size 5

bus.addedge(0,1,3)
bus.addedge(0,2,5)
bus.addedge(1,2,4)
bus.addedge(1,4,9)
bus.addedge(2,3,3)
bus.addedge(2,4,6)
bus.addedge(3,4,4)
train.addedge(0,1,1)
train.addedge(0,2,2)
train.addedge(1,2,2)
train.addedge(1,4,9)
train.addedge(2,3,1)
train.addedge(2,4,6)
train.addedge(3,4,8)
bus.addedge(1,0,3)
bus.addedge(2,0,5)
bus.addedge(2,1,4)
bus.addedge(4,1,9)
bus.addedge(3,2,3)
bus.addedge(4,2,6)
bus.addedge(4,3,4)
train.addedge(1,0,1)
train.addedge(2,0,2)
train.addedge(2,1,2)
train.addedge(4,1,9)
train.addedge(3,2,1)
train.addedge(4,2,6)
train.addedge(4,3,8)
'''

'''
#V size 6

bus.addedge(0,1,1)
bus.addedge(1,2,2)
bus.addedge(2,3,3)
bus.addedge(4,5,2)
train.addedge(0,1,1)
train.addedge(1,2,3)
train.addedge(2,3,2)
train.addedge(4,5,5)
bus.addedge(1,0,1)
bus.addedge(2,1,2)
bus.addedge(3,2,3)
bus.addedge(5,4,2)
train.addedge(1,0,1)
train.addedge(2,1,3)
train.addedge(3,2,2)
train.addedge(5,4,5)
'''
# our memorization algorithm has 2 part of a graph not 2 graph
# for exmp (we have 20 cities) between 1nd and 2nd cities there is train station  we add it between 20 21


aimed = int(input("Which city do you want to transport (number 0-80) :"))
start = time.time()
u = train.BellmanFord(0, aimed)  # Calculating both the distances
o = bus.BellmanFord(0, aimed)
shortest = min(u, o)
print("Shortest path from İstanbul-Harem to i : ", shortest)

end = time.time()

print("Running time of algorithm: ", (end - start))
